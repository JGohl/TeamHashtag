# %%
#import dependencies
import csv
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from datetime import datetime
from collections import Counter
import glob
import os

# %%
#define path for all files in work folder
path = r'' 
all_files = glob.glob(os.path.join(path, "*.csv"))

#create empty dataframe and list for dataframe build
frame = pd.DataFrame()
list_ = []

#loop through all files in work folder, select columns, and convert publish_date column to datetime format
for file_ in all_files:
    df = pd.read_csv(file_,index_col=None, header=0)
    df_edit = pd.DataFrame(df[['external_author_id', 
                              'author', 
                              'content', 
                              'region', 
                              'language', 
                              'publish_date',
                              'following', 
                              'followers',
                             'account_type',
                             'account_category',
                             'retweet',
                             'tweet_id']])
    df_edit['publish_date'] = df_edit['publish_date'].str.split(' ', expand=True)
    df_edit['publish_date'] = pd.to_datetime(df_edit['publish_date'])
    list_.append(df_edit)

#concat appended list into single data frame
frame = pd.concat(list_)
frame.head()
# Out:
# /Users/DocsMac/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/DocsMac/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (10,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/DocsMac/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (0,15,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    external_author_id  author  \
# 0  906000000000000000  10_GOP
# 1  906000000000000000  10_GOP
# 2  906000000000000000  10_GOP
# 3  906000000000000000  10_GOP
# 4  906000000000000000  10_GOP
#
#                                              content   region language  \
# 0  "We have a sitting Democrat US Senator on tria...  Unknown  English
# 1  Marshawn Lynch arrives to game in anti-Trump s...  Unknown  English
# 2  Daughter of fallen Navy Sailor delivers powerf...  Unknown  English
# 3  JUST IN: President Trump dedicates Presidents ...  Unknown  English
# 4  19,000 RESPECTING our National Anthem! #StandF...  Unknown  English
#
#   publish_date  following  followers account_type account_category  retweet  \
# 0   2017-10-01       1052       9636        Right       RightTroll        0
# 1   2017-10-01       1054       9637        Right       RightTroll        0
# 2   2017-10-01       1054       9637        Right       RightTroll        1
# 3   2017-10-01       1062       9642        Right       RightTroll        0
# 4   2017-10-01       1050       9645        Right       RightTroll        1
#
#              tweet_id
# 0  914580356430536707
# 1  914621840496189440
# 2  914623490375979008
# 3  914639143690555392
# 4  914312219952861184

# %%
#categorize publish_date into new column time_period

pre_analysis = frame['publish_date'] < pd.to_datetime('7/1/2015')
before = (frame['publish_date'] > pd.to_datetime('6/30/2015')) & (frame['publish_date'] <= pd.to_datetime('3/1/2016')) 
during = (frame['publish_date'] > pd.to_datetime('3/1/2016'))  & (frame['publish_date'] <= pd.to_datetime('12/1/2016'))
after = (frame['publish_date'] > pd.to_datetime('12/1/2016')) & (frame['publish_date'] <= pd.to_datetime('6/30/2017'))
post_analysis = frame['publish_date'] > pd.to_datetime('7/1/2017')

frame.loc[before, "time_period"] = 'Pre-election'
frame.loc[during, "time_period"] = 'Election season'
frame.loc[after, "time_period"] = 'Post-election'
frame.loc[pre_analysis, "time_period"] = 'Pre-analysis'
frame.loc[post_analysis, "time_period"] = 'Post-analysis'
frame.head()
# Out:
#    external_author_id  author  \
# 0  906000000000000000  10_GOP
# 1  906000000000000000  10_GOP
# 2  906000000000000000  10_GOP
# 3  906000000000000000  10_GOP
# 4  906000000000000000  10_GOP
#
#                                              content   region language  \
# 0  "We have a sitting Democrat US Senator on tria...  Unknown  English
# 1  Marshawn Lynch arrives to game in anti-Trump s...  Unknown  English
# 2  Daughter of fallen Navy Sailor delivers powerf...  Unknown  English
# 3  JUST IN: President Trump dedicates Presidents ...  Unknown  English
# 4  19,000 RESPECTING our National Anthem! #StandF...  Unknown  English
#
#   publish_date  following  followers account_type account_category  retweet  \
# 0   2017-10-01       1052       9636        Right       RightTroll        0
# 1   2017-10-01       1054       9637        Right       RightTroll        0
# 2   2017-10-01       1054       9637        Right       RightTroll        1
# 3   2017-10-01       1062       9642        Right       RightTroll        0
# 4   2017-10-01       1050       9645        Right       RightTroll        1
#
#              tweet_id    time_period
# 0  914580356430536707  Post-analysis
# 1  914621840496189440  Post-analysis
# 2  914623490375979008  Post-analysis
# 3  914639143690555392  Post-analysis
# 4  914312219952861184  Post-analysis

# %%
#get count of time_periods in complete dataframe (total count of rows = 2,945,013)
frame_count = frame['time_period'].value_counts()
frame_count
# Out:
# Pre-election       817992
# Election season    816524
# Post-election      760125
# Post-analysis      382867
# Pre-analysis       167505
# Name: time_period, dtype: int64

# %%
# find the followers 
type_count = frame['followers'].value_counts()
type_count = type_count.reset_index()
print(type_count.head)
# Out:
# <bound method NDFrame.head of         index  followers
# 0           0      13825
# 1           2      10935
# 2           1       9544
# 3           4       7445
# 4           5       7096
# 5           7       6075
# 6           3       5774
# 7           6       5607
# 8           8       5067
# 9          82       4473
# 10         83       4451
# 11         81       4160
# 12         88       4104
# 13        103       4031
# 14         95       3914
# 15        113       3721
# 16          9       3711
# 17         90       3689
# 18         96       3591
# 19        104       3484
# 20         80       3470
# 21         94       3446
# 22         11       3413
# 23        151       3400
# 24         89       3382
# 25         10       3376
# 26         86       3339
# 27        114       3321
# 28         97       3300
# 29        148       3289
# ...       ...        ...
# 66333   39600          1
# 66334   67169          1
# 66335   53945          1
# 66336   49851          1
# 66337   58047          1
# 66338  140007          1
# 66339   53944          1
# 66340   38480          1
# 66341   34755          1
# 66342  127644          1
# 66343   49848          1
# 66344   78471          1
# 66345   92812          1
# 66346  103059          1
# 66347  109204          1
# 66348  113302          1
# 66349  102003          1
# 66350   97901          1
# 66351   69219          1
# 66352   63068          1
# 66353   42582          1
# 66354   33457          1
# 66355   39602          1
# 66356   41653          1
# 66357   55994          1
# 66358   70272          1
# 66359   66178          1
# 66360   76423          1
# 66361   90766          1
# 66362   55247          1
#
# [66363 rows x 2 columns]>

# %%
type_count = frame['author'].value_counts()
type_count = type_count.reset_index()
print(type_count.head)
# Out:
# <bound method NDFrame.head of                 index  author
# 0             EXQUOTE   59174
# 1       SCREAMYMONKEY   44001
# 2       AMELIEBALDWIN   35261
# 3       WORLDNEWSPOLI   35155
# 4     TODAYPITTSBURGH   33602
# 5       SPECIALAFFAIR   32556
# 6        SEATTLE_POST   30793
# 7            FINDDIET   29038
# 8     KANSASDAILYNEWS   28806
# 9         ROOMOFRUMOR   28351
# 10       DAILYSANFRAN   27996
# 11    WORLDOFHASHTAGS   23724
# 12    COVFEFENATIONUS   23544
# 13        JENN_ABRAMS   22849
# 14    CHICAGODAILYNEW   22148
# 15           RIAFANRU   21461
# 16     POLITICS_T0DAY   21444
# 17           FUNDDIET   19992
# 18         BERLINBOTE   19658
# 19     CHESPLAYSCHESS   19216
# 20        TODAYNYCITY   18498
# 21    ONLINECLEVELAND   17666
# 22            HYDDROX   17384
# 23     OLD_NEW_POLICY   15418
# 24       TODAYINSYRIA   15401
# 25       NEWORLEANSON   14861
# 26         ARM_2_ALAN   14721
# 27        CHRIXMORGAN   14705
# 28      DAILYSANDIEGO   14381
# 29    DAILYLOSANGELES   14122
# ...               ...     ...
# 2813      ABBASSHUKRI       1
# 2814      MAISURGANIM       1
# 2815         STERRSAM       1
# 2816    RAYLEENNEELAM       1
# 2817      IWANOWAFAJA       1
# 2818  BLACKTIVISTDAVE       1
# 2819        DEON_LIEW       1
# 2820     KHALEDBAKRI7       1
# 2821     INSTASEX_TOP       1
# 2822       459JISALGE       1
# 2823      HAIDARQUSAY       1
# 2824      MECHTATELI_       1
# 2825       ACTIVEMIKR       1
# 2826     DUBOSEBELIKE       1
# 2827  ARTEMBOGACHENKO       1
# 2828   HUSEINALJABBER       1
# 2829        PRIBYSHIN       1
# 2830     KOTZZZLOVRED       1
# 2831        F_HANKARD       1
# 2832     ERVIN_ALFORD       1
# 2833      KADENMCCRAY       1
# 2834       NEVICHENKO       1
# 2835       SHAKURUSUF       1
# 2836    HEREANDTHERE_       1
# 2837     BUHOIINSIDER       1
# 2838        VKOSYREVA       1
# 2839  ALWAYSHUNGRYBAE       1
# 2840        KZUNIGA26       1
# 2841        MAH_ELNAF       1
# 2842      LAMARMUTANT       1
#
# [2843 rows x 2 columns]>

# %%
# Find the number of Following
type_count = frame['following'].value_counts()
type_count = type_count.reset_index()
print(type_count.head)
# Out:
# <bound method NDFrame.head of        index  following
# 0          2      60844
# 1          0      58414
# 2          3      37714
# 3          5      21025
# 4         68      12092
# 5         74       9905
# 6         65       7272
# 7          7       6816
# 8        247       5706
# 9        246       5435
# 10       120       5359
# 11        34       5316
# 12        92       5182
# 13        64       5125
# 14       253       4965
# 15       115       4940
# 16       248       4792
# 17        40       4781
# 18         1       4694
# 19      5001       4628
# 20       518       4249
# 21        69       4195
# 22        93       4047
# 23       549       3906
# 24       605       3879
# 25       284       3877
# 26       245       3809
# 27        70       3724
# 28      1479       3646
# 29       136       3601
# ...      ...        ...
# 28194  19467          1
# 28195  17418          1
# 28196  21512          1
# 28197  15365          1
# 28198  23563          1
# 28199  21514          1
# 28200  24908          1
# 28201  25610          1
# 28202  23565          1
# 28203  17422          1
# 28204  75542          1
# 28205  39215          1
# 28206  24880          1
# 28207  26929          1
# 28208  19458          1
# 28209  21505          1
# 28210  26429          1
# 28211  32574          1
# 28212  31749          1
# 28213  39214          1
# 28214  20788          1
# 28215  16181          1
# 28216  42003          1
# 28217  48144          1
# 28218  20283          1
# 28219  74010          1
# 28220  66598          1
# 28221  33814          1
# 28222  44051          1
# 28223  42702          1
#
# [28224 rows x 2 columns]>

# %%
type_count = frame['author'].value_counts()
type_count = type_count.reset_index()
print(type_count.head)
# Out:
# <bound method NDFrame.head of                 index  author
# 0             EXQUOTE   59174
# 1       SCREAMYMONKEY   44001
# 2       AMELIEBALDWIN   35261
# 3       WORLDNEWSPOLI   35155
# 4     TODAYPITTSBURGH   33602
# 5       SPECIALAFFAIR   32556
# 6        SEATTLE_POST   30793
# 7            FINDDIET   29038
# 8     KANSASDAILYNEWS   28806
# 9         ROOMOFRUMOR   28351
# 10       DAILYSANFRAN   27996
# 11    WORLDOFHASHTAGS   23724
# 12    COVFEFENATIONUS   23544
# 13        JENN_ABRAMS   22849
# 14    CHICAGODAILYNEW   22148
# 15           RIAFANRU   21461
# 16     POLITICS_T0DAY   21444
# 17           FUNDDIET   19992
# 18         BERLINBOTE   19658
# 19     CHESPLAYSCHESS   19216
# 20        TODAYNYCITY   18498
# 21    ONLINECLEVELAND   17666
# 22            HYDDROX   17384
# 23     OLD_NEW_POLICY   15418
# 24       TODAYINSYRIA   15401
# 25       NEWORLEANSON   14861
# 26         ARM_2_ALAN   14721
# 27        CHRIXMORGAN   14705
# 28      DAILYSANDIEGO   14381
# 29    DAILYLOSANGELES   14122
# ...               ...     ...
# 2813      ABBASSHUKRI       1
# 2814      MAISURGANIM       1
# 2815         STERRSAM       1
# 2816    RAYLEENNEELAM       1
# 2817      IWANOWAFAJA       1
# 2818  BLACKTIVISTDAVE       1
# 2819        DEON_LIEW       1
# 2820     KHALEDBAKRI7       1
# 2821     INSTASEX_TOP       1
# 2822       459JISALGE       1
# 2823      HAIDARQUSAY       1
# 2824      MECHTATELI_       1
# 2825       ACTIVEMIKR       1
# 2826     DUBOSEBELIKE       1
# 2827  ARTEMBOGACHENKO       1
# 2828   HUSEINALJABBER       1
# 2829        PRIBYSHIN       1
# 2830     KOTZZZLOVRED       1
# 2831        F_HANKARD       1
# 2832     ERVIN_ALFORD       1
# 2833      KADENMCCRAY       1
# 2834       NEVICHENKO       1
# 2835       SHAKURUSUF       1
# 2836    HEREANDTHERE_       1
# 2837     BUHOIINSIDER       1
# 2838        VKOSYREVA       1
# 2839  ALWAYSHUNGRYBAE       1
# 2840        KZUNIGA26       1
# 2841        MAH_ELNAF       1
# 2842      LAMARMUTANT       1
#
# [2843 rows x 2 columns]>

# %%
type_count = frame['author'].value_counts()
type_count = type_count.reset_index()
print(type_count.head(1581))
# Out:
#                 index  author
# 0             EXQUOTE   59174
# 1       SCREAMYMONKEY   44001
# 2       AMELIEBALDWIN   35261
# 3       WORLDNEWSPOLI   35155
# 4     TODAYPITTSBURGH   33602
# 5       SPECIALAFFAIR   32556
# 6        SEATTLE_POST   30793
# 7            FINDDIET   29038
# 8     KANSASDAILYNEWS   28806
# 9         ROOMOFRUMOR   28351
# 10       DAILYSANFRAN   27996
# 11    WORLDOFHASHTAGS   23724
# 12    COVFEFENATIONUS   23544
# 13        JENN_ABRAMS   22849
# 14    CHICAGODAILYNEW   22148
# 15           RIAFANRU   21461
# 16     POLITICS_T0DAY   21444
# 17           FUNDDIET   19992
# 18         BERLINBOTE   19658
# 19     CHESPLAYSCHESS   19216
# 20        TODAYNYCITY   18498
# 21    ONLINECLEVELAND   17666
# 22            HYDDROX   17384
# 23     OLD_NEW_POLICY   15418
# 24       TODAYINSYRIA   15401
# 25       NEWORLEANSON   14861
# 26         ARM_2_ALAN   14721
# 27        CHRIXMORGAN   14705
# 28      DAILYSANDIEGO   14381
# 29    DAILYLOSANGELES   14122
# ...               ...     ...
# 1551    LOREENPAOLERA     107
# 1552       WERNERBOCH     107
# 1553   VANESSA_A_LOTT     107
# 1554     ISOKTOBEMARK     107
# 1555    MYQUICKSILVER     107
# 1556         ZLOYKURS     106
# 1557  BLACK_ELEVATION     106
# 1558     SHIELDSCLINT     106
# 1559      BERT_HENLEY     105
# 1560    DONATELLOJACK     105
# 1561   JORDANSHELTONW     105
# 1562   MEMYSELFHAILEY     105
# 1563  JAWORSKIKATRINA     104
# 1564    DJKATKATKATIE     104
# 1565  KOLRADSKIY_ZHUK     104
# 1566   MEGGIEMCKENZIE     104
# 1567  BLACKERTHEBERR5     104
# 1568         MYROMYRA     103
# 1569     PORTER_2TYPE     103
# 1570        OCIMNOCXI     103
# 1571      ARTHCLAUDIA     103
# 1572     ODESSANEWS24     102
# 1573         LADAVISH     102
# 1574        JJ_WALSHJ     102
# 1575       ESAYL_ININ     101
# 1576  ALBERTA_HAYNESS     101
# 1577          KELVSOK     101
# 1578       ELEVEN_GOP     101
# 1579    ITSREALROBERT     100
# 1580    ROBERTHUGHESS     100
#
# [1581 rows x 2 columns]

# %%
# binning by count followers

bins = [1, 100, 200, 500, 2000, 5000, 10000]

# group names
group_names = ["veryfew", "100", "200", "500", "5000", "10000 or more"]

# %%
frame["follower_bin"] = pd.cut(frame["followers"], bins, labels=group_names)

# %%
frame.head()
# Out:
#    external_author_id  author  \
# 0  906000000000000000  10_GOP
# 1  906000000000000000  10_GOP
# 2  906000000000000000  10_GOP
# 3  906000000000000000  10_GOP
# 4  906000000000000000  10_GOP
#
#                                              content   region language  \
# 0  "We have a sitting Democrat US Senator on tria...  Unknown  English
# 1  Marshawn Lynch arrives to game in anti-Trump s...  Unknown  English
# 2  Daughter of fallen Navy Sailor delivers powerf...  Unknown  English
# 3  JUST IN: President Trump dedicates Presidents ...  Unknown  English
# 4  19,000 RESPECTING our National Anthem! #StandF...  Unknown  English
#
#   publish_date  following  followers account_type account_category  retweet  \
# 0   2017-10-01       1052       9636        Right       RightTroll        0
# 1   2017-10-01       1054       9637        Right       RightTroll        0
# 2   2017-10-01       1054       9637        Right       RightTroll        1
# 3   2017-10-01       1062       9642        Right       RightTroll        0
# 4   2017-10-01       1050       9645        Right       RightTroll        1
#
#              tweet_id    time_period   follower_bin following_bin
# 0  914580356430536707  Post-analysis  10000 or more           NaN
# 1  914621840496189440  Post-analysis  10000 or more           NaN
# 2  914623490375979008  Post-analysis  10000 or more           NaN
# 3  914639143690555392  Post-analysis  10000 or more           NaN
# 4  914312219952861184  Post-analysis  10000 or more           NaN

# %%
df3 = frame["follower_bin"].value_counts()
df3 = pd.DataFrame(df3)
df3 = df3.reset_index()
df3
# Out:
#            index  follower_bin
# 0            500        801829
# 1           5000        408552
# 2            200        346017
# 3        veryfew        267665
# 4            100        243166
# 5  10000 or more        108354

# %%
x_axis = group_names

plt.bar(x_axis, df3['follower_bin'])
# Out:
# <BarContainer object of 6 artists>

# %%
#following 

bins = [10, 25, 50, 100, 200]

group_names = ["25", "50", "100", "200 or more"]

# %%
df4 = frame["following_bin"].value_counts()
df4 = pd.DataFrame(df4)
df4 = df4.reset_index()
df4
# Out:
#          index  following_bin
# 0  200 or more         145365
# 1          100         125105
# 2           50          45392
# 3           25          14221

# %%
x_axis = group_names

plt.bar(x_axis, df4['following_bin'])
# Out:
# <BarContainer object of 4 artists>

# %%
#What follows here is somewhat not too useful!!!

#Ignore most of it - some df stuff that matters to the data

# %%
following = [25, 50, 100, 200]
x_axis = followers #np.arange(len(followers))

# %%
df4 = frame.groupby("following")

# %%
df4.max()
# Out:
#                     author    language publish_date  followers account_type  \
# following
# -1                RIAFANRU     Russian   2016-08-11         -1      Russian
#  0           _OLEG_EREMEEV  Vietnamese   2018-05-30     109722         news
#  1             ZWEIG_MARIA       Uzbek   2017-12-24      92673         news
#  2            WATSONTAYTAY  Vietnamese   2017-12-24      40259         news
#  3             YOLOBUHURTO  Vietnamese   2017-12-06      92889      Russian
#  4             YOLOBUHURTO  Vietnamese   2018-01-05      93628         news
#  5         WARRIORS_AZTLAN  Vietnamese   2017-12-24      93631         news
#  6            WATSONTAYTAY       Uzbek   2017-12-24      94567         news
#  7            TRUENEUTRAL0  Vietnamese   2017-12-24      95586         news
#  8          THOMAS_GERSTER       Uzbek   2017-12-24     104089         news
#  9            TATIANAMAXTV       Uzbek   2017-12-24     109808         news
#  10        SYLVIELEFEVRIER       Uzbek   2017-10-04     110155         news
#  11           UMARKHALED05       Uzbek   2017-11-06      92705      Russian
#  12         THEFOUNDINGSON       Uzbek   2017-09-26      92847      Russian
#  13           TATIANAMAXTV       Uzbek   2017-11-21       1985        local
#  14        _YOUR_LIFESTYLE  Vietnamese   2017-10-21      17732      Russian
#  15        _YOUR_LIFESTYLE       Uzbek   2017-11-06       6805      Russian
#  16        _YOUR_LIFESTYLE       Uzbek   2017-09-07        944      Russian
#  17        _YOUR_LIFESTYLE       Uzbek   2017-11-21      22762      Russian
#  18         WHATSUPPPADAMS       Uzbek   2017-05-29       1978      Russian
#  19            VOVAMERKUSH   Ukrainian   2017-09-11      41106      Russian
#  20           TATIANAMAXTV       Uzbek   2017-11-17      17848      Russian
#  21          SOSNOVSKYANNA       Uzbek   2017-09-03      40285      Russian
#  22         VERRELLPORTIER       Uzbek   2017-08-24      45627      Russian
#  23               SPBSPORT       Uzbek   2018-05-30      45543      Russian
#  24            VARGINSLAVA       Uzbek   2017-09-24     108142      Russian
#  25            YOLOBUHURTO       Uzbek   2017-12-06     108138      Russian
#  26        ZINCLINEDCOFFIN       Uzbek   2017-11-28     108105         news
#  27          TERRYBEVER_LY       Uzbek   2017-08-23     110313      Russian
#  28          TERRYBEVER_LY  Vietnamese   2017-08-18     111149      Russian
# ...                    ...         ...          ...        ...          ...
#  76170             TEN_GOP     English   2017-03-19      97145        Right
#  76171             TEN_GOP     English   2017-03-16      95907        Right
#  76172             TEN_GOP     English   2017-03-16      95903        Right
#  76173             TEN_GOP     English   2017-03-21      98397        Right
#  76176             TEN_GOP     English   2017-03-20      98204        Right
#  76177             TEN_GOP     English   2017-03-20      98213        Right
#  76179             TEN_GOP     English   2017-03-16      95895        Right
#  76182             TEN_GOP     English   2017-03-20      97968        Right
#  76183             TEN_GOP     English   2017-03-20      97990        Right
#  76184             TEN_GOP  Lithuanian   2017-03-20      98180        Right
#  76186             TEN_GOP     English   2017-03-11      93710        Right
#  76188             TEN_GOP     English   2017-03-11      93678        Right
#  76189             TEN_GOP     English   2017-03-16      95814        Right
#  76190             TEN_GOP     English   2017-03-16      95808        Right
#  76192             TEN_GOP     English   2017-03-20      97532        Right
#  76193             TEN_GOP     English   2017-03-16      95759        Right
#  76194             TEN_GOP     English   2017-03-15      95707        Right
#  76197             TEN_GOP     English   2017-03-20      97323        Right
#  76198             TEN_GOP     English   2017-03-19      97278        Right
#  76199             TEN_GOP     English   2017-03-15      95690        Right
#  76200             TEN_GOP     English   2017-03-15      95641        Right
#  76202             TEN_GOP     English   2017-03-15      95603        Right
#  76203             TEN_GOP     English   2017-03-19      97180        Right
#  76204             TEN_GOP     English   2017-03-19      97191        Right
#  76205             TEN_GOP     English   2017-03-15      95188        Right
#  76206             TEN_GOP     English   2017-03-15      95193        Right
#  76207             TEN_GOP     English   2017-03-15      95202        Right
#  76208             TEN_GOP     English   2017-03-15      95218        Right
#  76209             TEN_GOP     English   2017-03-15      95332        Right
#  76210             TEN_GOP     English   2017-03-15      95378        Right
#
#           account_category  retweet             tweet_id   follower_bin  \
# following
# -1              NonEnglish        1   763533169081589760            NaN
#  0                 Unknown        1  1001916188459438082  10000 or more
#  1                 Unknown        1   944738386996334598  10000 or more
#  2                 Unknown        1   944866752076361728  10000 or more
#  3                 Unknown        1   938445435898859521  10000 or more
#  4                 Unknown        1   949339836992950272           5000
#  5                 Unknown        1   944876635358195713           5000
#  6                 Unknown        1   944877971369807872            500
#  7                 Unknown        1   944882707108171776            500
#  8                 Unknown        1   944886321289617408            500
#  9                 Unknown        1   944935873040338944           5000
#  10             RightTroll        1   915607199254269954           5000
#  11                Unknown        1   927517925128450048            500
#  12                Unknown        1   912806023836008449            500
#  13                Unknown        1   932979203405950976            500
#  14                Unknown        1   921561007847362560            100
#  15                Unknown        1   927575291932893184  10000 or more
#  16                Unknown        1   905938220466266112            500
#  17                Unknown        1   933047645819502592        veryfew
#  18                Unknown        1   869180423712239616            500
#  19                Unknown        1   907385176434540544            500
#  20                Unknown        1   931456704067330050  10000 or more
#  21                Unknown        1   904333988650778625            100
#  22                Unknown        1   900869172950970368           5000
#  23             RightTroll        1  1001931582557556737           5000
#  24                Unknown        1   911921304751759361            100
#  25                Unknown        1   938454398535196673           5000
#  26                Unknown        1   935625202540711936            100
#  27                Unknown        1   900437764604297216            100
#  28                Unknown        1   898658069189718016            100
# ...                    ...      ...                  ...            ...
#  76170          RightTroll        0   843568835760332800            NaN
#  76171          RightTroll        0   842245241956626432            NaN
#  76172          RightTroll        0   842241746276880384            NaN
#  76173          RightTroll        0   844220253039136768            NaN
#  76176          RightTroll        0   843968305924882432            NaN
#  76177          RightTroll        1   843971910023176193            NaN
#  76179          RightTroll        1   842235011709435904            NaN
#  76182          RightTroll        1   843856202702446592            NaN
#  76183          RightTroll        0   843864132403257348            NaN
#  76184          RightTroll        1   843953895630163968            NaN
#  76186          RightTroll        0   840395679625240576            NaN
#  76188          RightTroll        0   840381077243944960            NaN
#  76189          RightTroll        0   842195945689239552            NaN
#  76190          RightTroll        0   842191771115241472            NaN
#  76192          RightTroll        0   843657960303730688            NaN
#  76193          RightTroll        1   842168484356222976            NaN
#  76194          RightTroll        0   842146708070981632            NaN
#  76197          RightTroll        0   843614253932199936            NaN
#  76198          RightTroll        0   843605977798594560            NaN
#  76199          RightTroll        0   842136816027291648            NaN
#  76200          RightTroll        0   842117524686741505            NaN
#  76202          RightTroll        1   842091240925483008            NaN
#  76203          RightTroll        0   843580758904070144            NaN
#  76204          RightTroll        0   843588093860962304            NaN
#  76205          RightTroll        0   841828171053977601            NaN
#  76206          RightTroll        0   841831124624007168            NaN
#  76207          RightTroll        1   841833576727367682            NaN
#  76208          RightTroll        0   841838822581141504            NaN
#  76209          RightTroll        0   841871489758560256            NaN
#  76210          RightTroll        1   841885164158496769            NaN
#
#           following_bin
# following
# -1                  NaN
#  0                  NaN
#  1                  NaN
#  2                  NaN
#  3                  NaN
#  4                  NaN
#  5                  NaN
#  6                  NaN
#  7                  NaN
#  8                  NaN
#  9                  NaN
#  10                 NaN
#  11                  25
#  12                  25
#  13                  25
#  14                  25
#  15                  25
#  16                  25
#  17                  25
#  18                  25
#  19                  25
#  20                  25
#  21                  25
#  22                  25
#  23                  25
#  24                  25
#  25                  25
#  26                  50
#  27                  50
#  28                  50
# ...                 ...
#  76170              NaN
#  76171              NaN
#  76172              NaN
#  76173              NaN
#  76176              NaN
#  76177              NaN
#  76179              NaN
#  76182              NaN
#  76183              NaN
#  76184              NaN
#  76186              NaN
#  76188              NaN
#  76189              NaN
#  76190              NaN
#  76192              NaN
#  76193              NaN
#  76194              NaN
#  76197              NaN
#  76198              NaN
#  76199              NaN
#  76200              NaN
#  76202              NaN
#  76203              NaN
#  76204              NaN
#  76205              NaN
#  76206              NaN
#  76207              NaN
#  76208              NaN
#  76209              NaN
#  76210              NaN
#
# [28224 rows x 10 columns]

# %%
following = [25, 50, 100, 200]
x_axis = np.arange(len(following))

# %%
plt.bar(x_axis, following, color='r', alpha=1, align="center")
# Out:
# <BarContainer object of 4 artists>

# %%
followers_count = frame['followers'].value_counts()
followers_count = lang_count.reset_index()
print(followers_count.head(8))
# Out:
#    level_0      index  language
# 0        0    English   2116867
# 1        1    Russian    610943
# 2        2     German     86983
# 3        3  Ukrainian     38669
# 4        4    Italian     18063
# 5        5    Serbian      9480
# 6        6      Uzbek      9334
# 7        7  Bulgarian      9236

# %%
type_count = frame['time_period'].value_counts()
type_count = type_count.reset_index()
print(type_count.head)
# Out:
# <bound method NDFrame.head of              index  time_period
# 0     Pre-election       817992
# 1  Election season       816524
# 2    Post-election       760125
# 3    Post-analysis       382867
# 4     Pre-analysis       167505>

# %%
type_count = frame['account_category'].value_counts()
type_count = type_count.reset_index()
print(type_count.head)
# Out:
# <bound method NDFrame.head of           index  account_category
# 0    NonEnglish            820803
# 1    RightTroll            711668
# 2      NewsFeed            598226
# 3     LeftTroll            427141
# 4  HashtagGamer            241786
# 5    Commercial            121904
# 6       Unknown             13539
# 7    Fearmonger             11140>

# %%
# find and list top 4 language breakdown of tweets
lang_count = frame['language'].value_counts()
lang_count = lang_count.reset_index()
print(lang_count.head(4))

# graph tweets by language
labels = lang_count['index'].head(4)
plt.pie(lang_count['language'].head(4), labels=labels, startangle=0)
plt.axis('equal')
# Out:
#        index  language
# 0    English   2116867
# 1    Russian    610943
# 2     German     86983
# 3  Ukrainian     38669
# (-1.1192320398371511, 1.1009158130738101, -1.111716423521399, 1.12027046682135)

# %%
# find and list top 7 account type breakdown of tweets
type_count = frame['account_type'].value_counts()
type_count = type_count.reset_index()
print(type_count.head(7))

# graph tweets by type
labels = type_count['index'].head(7)
plt.pie(type_count['account_type'].head(7), labels=labels, startangle=10)
plt.axis('equal')
# Out:
#         index  account_type
# 0       Right        711668
# 1     Russian        704917
# 2       local        459220
# 3        Left        427141
# 4   Hashtager        241786
# 5        news        139006
# 6  Commercial        121904
# (-1.10736957821143,
#  1.1014065050313646,
#  -1.1135569138663843,
#  1.1076712695574675)

# %%
# find and list account category breakdown of tweets
category_count = frame['account_category'].value_counts()
category_count = category_count.reset_index()
print(category_count)

# graph tweets by language
labels = category_count['index']
plt.pie(category_count['account_category'], labels=labels, startangle=20)
plt.axis('equal')
# Out:
#           index  account_category
# 0    NonEnglish            820803
# 1    RightTroll            711668
# 2      NewsFeed            598226
# 3     LeftTroll            427141
# 4  HashtagGamer            241786
# 5    Commercial            121904
# 6       Unknown             13539
# 7    Fearmonger             11140
# (-1.1333940506256628,
#  1.1041802424817604,
#  -1.1238238686533835,
#  1.110749493179307)

# %%
# keep only rows where the language is English
english_troll = frame[frame['language'].str.match('English')]
english_troll.index = pd.RangeIndex(len(english_troll.index))
english_troll.head()
# Out:
#    external_author_id  author  \
# 0  906000000000000000  10_GOP
# 1  906000000000000000  10_GOP
# 2  906000000000000000  10_GOP
# 3  906000000000000000  10_GOP
# 4  906000000000000000  10_GOP
#
#                                              content   region language  \
# 0  "We have a sitting Democrat US Senator on tria...  Unknown  English
# 1  Marshawn Lynch arrives to game in anti-Trump s...  Unknown  English
# 2  Daughter of fallen Navy Sailor delivers powerf...  Unknown  English
# 3  JUST IN: President Trump dedicates Presidents ...  Unknown  English
# 4  19,000 RESPECTING our National Anthem! #StandF...  Unknown  English
#
#   publish_date  following  followers account_type account_category  retweet  \
# 0   2017-10-01       1052       9636        Right       RightTroll        0
# 1   2017-10-01       1054       9637        Right       RightTroll        0
# 2   2017-10-01       1054       9637        Right       RightTroll        1
# 3   2017-10-01       1062       9642        Right       RightTroll        0
# 4   2017-10-01       1050       9645        Right       RightTroll        1
#
#              tweet_id    time_period
# 0  914580356430536707  Post-analysis
# 1  914621840496189440  Post-analysis
# 2  914623490375979008  Post-analysis
# 3  914639143690555392  Post-analysis
# 4  914312219952861184  Post-analysis

# %%
# find most used words in content


words = []
for row in english_troll:
    csv_words = row[0:].split(" ")
    for i in csv_words:
        words.append(i)
    print(csv_words)

words_counted = []
for i in words:
    x = words.count(i)
    words_counted.append((i,x))

set(words_counted)
    





#content = (row[2] for row in english_troll)
#print("Most frequent value: {0}".format(Counter(content).most_common()[0][0]))
# Out:
# ['external_author_id']
# ['author']
# ['content']
# ['region']
# ['language']
# ['publish_date']
# ['following']
# ['followers']
# ['account_type']
# ['account_category']
# ['retweet']
# ['tweet_id']
# ['time_period']
# {('account_category', 1),
#  ('account_type', 1),
#  ('author', 1),
#  ('content', 1),
#  ('external_author_id', 1),
#  ('followers', 1),
#  ('following', 1),
#  ('language', 1),
#  ('publish_date', 1),
#  ('region', 1),
#  ('retweet', 1),
#  ('time_period', 1),
#  ('tweet_id', 1)}
